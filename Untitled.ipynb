# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv("dataset/clean_crypto_dataset.csv")
df.head()
# Out:
#          date      price    market_cap        volume cryptocurrency symbol  \
# 0  2014-01-01  4883.4581  9.278570e+10  2.593262e+07        Bitcoin    BTC
# 1  2014-02-01  4528.9427  8.604991e+10  4.259365e+08        Bitcoin    BTC
# 2  2014-03-01  5230.1490  9.937283e+10  1.732123e+08        Bitcoin    BTC
# 3  2014-04-01  4531.3672  8.609598e+10  4.922574e+08        Bitcoin    BTC
# 4  2014-05-01  4970.2206  9.443419e+10  8.935488e+08        Bitcoin    BTC
#
#    percent_change_24h
# 0              0.0000
# 1             -7.2595
# 2             15.4828
# 3            -13.3606
# 4              9.6848

# %%
df['date'] = pd.to_datetime(df['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                1560 non-null   datetime64[ns]
#  1   price               1560 non-null   float64
#  2   market_cap          1560 non-null   float64
#  3   volume              1560 non-null   float64
#  4   cryptocurrency      1560 non-null   object
#  5   symbol              1560 non-null   object
#  6   percent_change_24h  1560 non-null   float64
# dtypes: datetime64[ns](1), float64(4), object(2)
# memory usage: 85.4+ KB

# %%
df.isnull().sum()
# Out:
# date                  0
# price                 0
# market_cap            0
# volume                0
# cryptocurrency        0
# symbol                0
# percent_change_24h    0
# dtype: int64

# %%
df.describe()
# Out:
#                                 date         price    market_cap  \
# count                           1560   1560.000000  1.560000e+03
# mean   2020-06-16 01:50:46.153846272   2687.416834  8.279217e+10
# min              2014-01-01 00:00:00      0.000900  1.323995e+08
# 25%              2017-03-24 06:00:00      0.104950  1.362936e+09
# 50%              2020-06-16 00:00:00      4.327000  6.331399e+09
# 75%              2023-09-08 12:00:00    395.880800  5.242618e+10
# max              2026-12-01 00:00:00  53556.148700  1.017567e+12
# std                              NaN   8621.740334  1.764248e+11
#
#              volume  percent_change_24h
# count  1.560000e+03         1560.000000
# mean   5.018330e+08            3.749098
# min    1.088038e+06          -56.118300
# 25%    2.438940e+08           -5.652025
# 50%    4.969556e+08            0.419900
# 75%    7.574914e+08            6.912200
# max    9.992747e+08          423.798400
# std    2.893817e+08           33.577816

# %%
top_market = df.groupby('cryptocurrency')['market_cap'].mean().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,5))
top_market.plot(kind='bar', color='orange')
plt.title("Top 10 Cryptocurrencies by Average Market Cap")
plt.ylabel("Market Cap")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df[['price','market_cap','volume']].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Between Financial Features")
plt.show()

# %%
btc = df[df['cryptocurrency']=='Bitcoin']

plt.figure(figsize=(12,5))
plt.plot(btc['date'], btc['price'])
plt.title("Bitcoin Price Trend Over Time")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.show()

# %%
fig = px.line(df[df['cryptocurrency'].isin(['Bitcoin','Ethereum','Cardano','Litecoin'])],
              x='date', y='price', color='cryptocurrency',
              title="Multi Cryptocurrency Price Comparison")

fig.show()

# %%
btc = btc.sort_values('date')
btc['days'] = (btc['date'] - btc['date'].min()).dt.days

X = btc[['days']]
y = btc['price']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

y_pred = model.predict(X_test)

print("R2 Score:", r2_score(y_test, y_pred))
print("MAE:", mean_absolute_error(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
# Out:
# R2 Score: -3.0682672598687377
# MAE: 5599.616188189564
# MSE: 37919131.93077275

# %%
import os
import joblib

os.makedirs("model", exist_ok=True)
joblib.dump(model, "model/model.pkl")
# Out:
# ['model/model.pkl']

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.7.2
